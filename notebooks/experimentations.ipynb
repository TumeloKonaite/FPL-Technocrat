# %% [markdown]
# ## 1.  Experimenting with YouTube transcription

# %%
from youtube_transcript_api import YouTubeTranscriptApi
from agents import Agent, Runner
from dotenv import load_dotenv
import os
import yt_dlp
from typing import Any
import requests

# %%
load_dotenv(override=True)
# Out:
# True

# %%
video_id = "xO6K1OsqbTM"
ytt_api = YouTubeTranscriptApi()
transcript = ytt_api.fetch(video_id)

# %% [markdown]
# # combining the transcript into into one.

# %%
combined_transcript = " ".join(
    " ".join(snippet.text.split())
    for snippet in transcript.snippets
)

print(combined_transcript)
# Out:
# Is gameweek 32 the right week for all of us to be playing our wild cards? Or should we be delaying it later to like gameweek 35? What does the FA Cup mean? And actually, let's have a look at my team going into this week with five free transfers available. Is it the right time for me? Is it the right time for you? And generally, what should you be looking at over the next couple of weeks with gameweek 32 still being three weeks away? What is up everyone? FP Harry here. Before we dive in, 2,000 likes is the aim. Subscribe if you are new around here as well. Now, just a bit of an introduction and a scene setter for this video. Gameweek 32 is not for 3 weeks, right? We've got the international break, then we've got the allimportant FA Cup weekend, and then we've got gameweek 32 the week end after that. So, there is a lot of time to go between now and the next FPL deadline. And it's probably the most important two weeks where you don't do anything with your FPL team. And we're going to discuss in this video exactly why I think that is and why you shouldn't be making transfers even if you are certain in your mind that you think you're going to wild card in gameweek 32 because of all the FA Cup results and what they could do with your team. So this is just going to be a slightly more chatty, more sort of laid-back video with slightly less structure where I look at my team, I look at the potential results in the FA Cup and everything else to try and decide what it might mean for your team once those FA Cup results do come around. You might then not have another video for me for two weeks until those FA Cup games are out of the way. We might come back just before it to again tee things up as the FA Cup is starting. But that FA Cup weekend in two weeks time is the biggest nonFPL weekend left this season that will decide the doubles and blanks later on in the season. So if you really really want a wild card 32, I still urge you to not make any transfers. delete the app, log yourself out, come back once the FA Cup is out of the way and we start getting announcements of doubles and blanks for the rest of the season, particularly gameweek 33 and gameweek 34. But gameweek 31 is in the blank. It was the blank gameweek. I got 65 points, which is another green arrow. I've had four big green arrows on the bounce now going from 167k, a rank I felt like I was stagnating at. I needed to do something different. But actually what's quite interesting across those four weeks is I've rolled my transfer in pretty much all of those weeks. So I've now got five free transfers. I've got my wild card. I've got my free hit and my bench boost. So going into this break, yes, I'll be doing some planning. And once we get to gameweek 32, there are seven weeks of the season left. How far can I continue to push? Can I continue to turn things around? Get things moving in the right direction with five free threes and a wild card and the other chips still to play. So five points above my safety score. I moved from 47K to 36K. So again, moving in the right direction. I had 11 players out. Taroski, who was my only doubt going into the weekend, actually ended up being the hero of my gameweek. Although as a Chelsea fan, I really wish that he hadn't ended up being that. I mean, there were lots of clubs. I'm sure the fans in the comments of the likes of Liverpool, Chelsea, Spurs, and others, potentially Arsenal will be in the comments saying who's had the worst weekend. I think Spurs fans might end up winning that argument, but Chelsea are definitely up there. It does not feel a good time to be a Chelsea fan and a 3-0 win for Everton. Now, it would have been nice if we were going to drop points and I'm going to have to watch Chelsea lose that Drewsbury Hall could get involved in one of the three goals. Nothing for him, but three points there. Six for Tarosski. A few points across my midfield. I went with Bruno Fernandez captain. He got a goal in assist. Harry Wilson with my v ...

# %%
#instructions for the fpl agent
instructions = """You are an expert Fantasy Premier League (FPL) analyst.

Your task is to analyze FPL YouTube video transcripts and extract actionable, gameweek-specific insights. Focus on turning long-form content into structured, decision-ready outputs.

Objectives

From the transcript, identify and clearly summarise:

1. Gameweek Strategy
- Key strategy being discussed (for example: wildcard, bench boost, free hit)
- When and why to use chips
- Conditions or uncertainties affecting strategy (for example: FA Cup results, fixture changes)

2. Fixture Analysis
- Teams likely to have double or blank gameweeks
- Fixture quality (easy vs difficult)
- Dependencies (for example: if Team A wins, then Team B doubles)

3. Player Recommendations
Categorise players into:
- Locks: must-have players
- Strong Picks
- Differentials / Risky Picks
- Avoid / Uncertain Picks

Include reasoning such as form, fixtures, minutes, penalties, and role.

4. Transfer Strategy
- Suggested transfers between gameweeks
- Short-term vs long-term moves
- Planned swaps (for example: GW32 to GW33 transitions)

5. Captaincy Picks
- Best captain options for the gameweek
- Alternatives and reasoning

6. Chip Strategy
- When to use Wildcard
- When to use Bench Boost
- When to use Free Hit
- Ideal combinations (for example: wildcard GW32, then bench boost GW33)

7. Risks and Uncertainty
- Highlight anything not confirmed
- Explain what decisions depend on future results
- Clearly mark speculative vs confirmed insights

8. Key Takeaways
- Provide a concise TL;DR with the most important decisions

Output Format

Structure your response as:
- Strategy Summary
- Fixture Insights
- Player Picks (grouped)
- Transfer Plan
- Captaincy
- Chip Strategy
- Risks / What to Wait For
- Final Takeaways

Important Rules

- Do not repeat the transcript
- Extract insights only
- Prioritise actionable advice over description
- If the video is speculative, clearly state that
- Highlight conditional logic
- Be concise but insightful

Example Behaviour

If the transcript says early wildcard planning is uncertain due to FA Cup outcomes, you must:
- Flag it as speculative
- Identify the branching scenarios
- Provide different strategies for each scenario

Your goal is to make the user feel like they do not need to watch the video because they already have the best insights.
"""

# %%
# fplh = fpl harry
fplh_agent = Agent(
    name="FPLh",
    instructions= instructions,
)

result = await Runner.run(fplh_agent, combined_transcript)
print(result.final_output)
# Out:
# OPENAI_API_KEY is not set, skipping trace export
# **Strategy Summary**
#
# - **Do NOT make early transfers or lock in chips before the FA Cup:** The single most important action right now is patience. Avoid tinkering, transfers, or chip activation for Gameweek 32 or beyond until after the key FA Cup results and resulting fixture announcements, which will determine double and blank gameweeks.
# - **Wildcard GW32?** It’s *not essential* for everyone. If your squad is balanced and you have multiple free transfers, you may not gain value from a GW32 wildcard. Wait for the FA Cup and fixture info.
# - **Alternate chip plans:** Consider delaying the Wildcard to GW35, Free Hit in a big Double Gameweek, or activating Bench Boost when more information is available.
#
# ---
#
# **Fixture Insights**
#
# - **Doubles/Blanks hinge on FA Cup results:** All major fixture swings (especially DGW33/34 and blank GW34) depend on which teams progress in the FA Cup. Unexpected upsets could dramatically change the landscape.
#     - Example: If Chelsea or Arsenal go out, the expected doubles may not materialize.
# - **Doubles most likely in GW33/34:** Teams such as Arsenal, Brighton, Chelsea, Man City, and Newcastle *may* double, but this is still speculative.
#     - City almost certain to double due to their outstanding fixtures, but WHEN remains uncertain (GW33 vs GW34).
#     - Crystal Palace could also double (potentially GW33/GW36).
# - **Fixture Placement Uncertain:** Games might be moved to GW33 or left in GW34. TV scheduling and European involvement complicate matters.
# - **Fixture Quality:** Teams like Arsenal, City, Newcastle, Chelsea generally have good runs but many will play each other, making doubles less appealing for loading up.
#
# ---
#
# **Player Picks**
#
# *Highly provisional until fixtures confirmed. Across both chip and non-chip strategies, focus on:*
#
# - **Locks (If doubles confirmed):**
#     - Arsenal core (Saka, Gabriel/Odegaard): Great form, fixtures, high upside; especially if they double.
#     - Man City (Haaland, mid: Foden/KDB, Ederson/def): Essential if double confirmed.
#     - Newcastle (Gordon, Isak, one defender): Good price, mainstays for double coverage.
# - **Strong Picks:**
#     - Bruno Fernandes: Reliable minutes, on pens, potential captaincy in single GW.
#     - Chelsea (Palmer): If fixtures align, form pick, on pens, good for double/bench boost.
#     - Brighton (Joao Pedro, defenders): If strong run or double confirmed.
# - **Differentials/Risky:**
#     - Crystal Palace assets (Mateta, Richards, Henderson): Only if a double occurs.
#     - Dravka (GK) or cheapies from Burnley/Brentford if budget is tight and they double.
# - **Avoid/Uncertain:**
#     - Players from teams likely to blank, especially if no double and poor fixtures (e.g., assets from sides knocked out of FA Cup with few games to play).
#     - Anyone with recent injury doubts or minute uncertainty, particularly outside template teams.
#
# ---
#
# **Transfer Plan**
#
# - **Current Advice:** *Make NO transfers until after the FA Cup and fixture announcement.* Most pressing moves (out-of-form players, injury replacements) can be reassessed with more certainty.
# - **Short-term (if not wild carding):**
#     - Use accumulated free transfers after the break with more info.
#     - Target key doubles/offload single GW fodder.
# - **Long-term:**
#     - Save Wildcard if team is healthy, to maximize flexibility for late doubles/blanks, especially GW35 onward.
#
# ---
#
# **Captaincy**
#
# - **GW32:** If not on chips, Bruno Fernandes (due to reliability and fixture) is mentioned as the best captain. Others: Haaland, Saka, Palmer (if fixtures/doubles align).
# - **Later GWs:** To be confirmed once doubles are fixed, but often City/Arsenal assets will be prime picks.
# - *Always re-evaluate after fixture announcements.*
#
# ---
#
# **Chip Strategy**
#
# Currently, **ALL chip strategies are provisional** and extremely dependent on FA Cup/final fixture announcement. Options:
#
# - **Wildcard GW32** *only* if you need wholesale change and want to bench boost GW33.
#     - WC32 → BB33 → FH34 (if 34 is a blank)
#     - Pros: Sets up for a DGW bench boost.
#     - Cons: Drafts now appear weaker than just holding, especially if your team is already strong.
# - **Delay Wildcard (ideal if team is well set):** Wait until GW35 for max info on late doubles/blanks.
#     - WC35 → BB36 or BB37 (if new doubles appear)
#     - Use FH in big double or blank (GW33 or 34 depending)
#     - Allows targeting late-season uncertainty and injuries.
# - **Bench Boost/Free Hit:** Only after fixtures confirmed.
# - **Summary:**
#     - Early WC = max bench boost potential but may be sub-optimal if many single GWs/duds emerge.
#     - Late WC = flexibility, targets late double/blank chaos.
#
# ---
#
# **Risks / What to Wait For**
#
# - **FA Cup Results:** Will unlock which fixtures move and when. Up to four teams’ FA Cup progression will shift the entire DGW/BGW picture.
# - **Premier League Announcements:** Fixture scheduling post-FA Cup (days after the games) is ESSENTIAL before planning chips or transfers.
# - **Injury News:** International break = high injury risk; wait for updates.
# - **Speculative Points:** All planning without this info is just educated guesswork—do *not* act until the schedule settles.
#
# ---
#
# **Final Takeaways (TL;DR)**
#
# 1. **Do NOT activate Wildcard or any chips, or make early transfers, before the FA Cup and fixture announcements.**
# 2. **Wildcards in GW32 and GW35 are both viable but should be based on YOUR team’s needs and the final doubles picture.**
# 3. **Monitor FA Cup (esp. for Chelsea, Arsenal, City, Liverpool, West Ham, Leeds); their progress will dictate doubles/blanks.**
# 4. **Bench Boost is most powerful in a big double gameweek; don’t use it until 100% sure of maximum doublers.**
# 5. **Optimal strategy will become clear AFTER FA Cup weekend and fixture announcements — whoever waits will get the best outcome.**
# 6. **Don’t obsess over price changes; points potential matters more.**
# 7. **Check back after the break for finalized chip/player advice.**
#
# **Bottom line: Pause. Don’t act. Wait for FA Cup weekend and fixture announcements—only then decide chip and transfer strategies.**
#
# *You do NOT need need to watch the original video—these are the only actionable takeaways until the FA Cup and new fixtures are confirmed.*
# OPENAI_API_KEY is not set, skipping trace export

# %% [markdown]
# ## Experimenting with getting YouTube URLS

# %%
import yt_dlp

def get_latest_videos(channel_url, limit=5):
    ydl_opts = {
        "quiet": True,
        "extract_flat": True,
        "playlistend": limit,
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        result = ydl.extract_info(f"{channel_url}/videos", download=False)

    return result["entries"][:limit]

# %%
get_latest_videos("https://www.youtube.com/@FPLHarry")
# Out:
# [{'_type': 'url',
#   'ie_key': 'Youtube',
#   'id': 'xO6K1OsqbTM',
#   'url': 'https://www.youtube.com/watch?v=xO6K1OsqbTM',
#   'title': 'MY FPL GW32 FIRST THOUGHTS! 📝 WILDCARD DRAFT 🍟 & Fa Cup Impact | Fantasy Premier League Tips 2025/26',
#   'description': 'Here are my First Transfer Plans for FPL GW32!\n🏆 Previous 5 FPL Ranks: 510th, 1,345th, 3,814th, 5,401st & 6,470th! \n_____________\nLEAGUE CODES\n🏆 Subscriber League: Code: 5s23tm - link:...',
#   'duration': 1140.0,
#   'channel_id': None,
#   'channel': None,
#   'channel_url': None,
#   'uploader': None,
#   'uploader_id': None,
#   'uploader_url': None,
#   'thumbnails': [{'url': 'https://i.ytimg.com/vi/xO6K1OsqbTM/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLB4LrmFyfw0d8jj1EjC7il2dWVf5A',
#     'height': 94,
#     'width': 168},
#    {'url': 'https://i.ytimg.com/vi/xO6K1OsqbTM/hqdefault.jpg?sqp=-oaymwEbCMQBEG5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLAdo-ho3G4f_cm4DhuFRGH0ulx9Pw',
#     'height': 110,
#     'width': 196},
#    {'url': 'https://i.ytimg.com/vi/xO6K1OsqbTM/hqdefault.jpg?sqp=-oaymwEcCPYBEIoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBQ1lriYrZOqldi5SOeN2Mt3BII-g',
#     'height': 138,
#     'width': 246},
#    {'url': 'https://i.ytimg.com/vi/xO6K1OsqbTM/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDq09JQR2ko0wVznGU6o8P9uEp_ag',
#     'height': 188,
#     'width': 336}],
#   'timestamp': None,
#   'release_timestamp': None,
#   'availability': None,
#   'view_count': 74667,
#   'live_status': None,
#   'channel_is_verified': True,
#   '__x_forwarded_for_ip': None},
#  {'_type': 'url',
#   'ie_key': 'Youtube',
#   'id': 'V3SO7Tt0DK8',
#   'url': 'https://www.youtube.com/watch?v=V3SO7Tt0DK8',
#   'title': 'FPL BLANK GW31 COMPLETE GUIDE ⁉️ Short Term vs Long Term... 🔮 | Fantasy Premier League Tips 2025/26',
#   'description': 'Everything you need to know for FPL GW31!\n🏆 Previous 5 FPL Ranks: 510th, 1,345th, 3,814th, 5,401st & 6,470th! \n_____________\nLEAGUE CODES\n🏆 League Code: (10p to Charity for everyone in...',
#   'duration': 1290.0,
#   'channel_id': None,
#   'channel': None,
#   'channel_url': None,
#   'uploader': None,
#   'uploader_id': None,
#   'uploader_url': None,
#   'thumbnails': [{'url': 'https://i.ytimg.com/vi/V3SO7Tt0DK8/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBivXN5CPimyxDicHVNOdyTEPlfoA',
#     'height': 94,
#     'width': 168},
#    {'url': 'https://i.ytimg.com/vi/V3SO7Tt0DK8/hqdefault.jpg?sqp=-oaymwEbCMQBEG5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLD5rTVhcAahJMnKF--03iFbN7cpbA',
#     'height': 110,
#     'width': 196},
#    {'url': 'https://i.ytimg.com/vi/V3SO7Tt0DK8/hqdefault.jpg?sqp=-oaymwEcCPYBEIoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDkq60_iMH_BgC2nXysstf3Sy6Asg',
#     'height': 138,
#     'width': 246},
#    {'url': 'https://i.ytimg.com/vi/V3SO7Tt0DK8/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBZghVoY5hO8TXbbP13uijJhE5dPA',
#     'height': 188,
#     'width': 336}],
#   'timestamp': None,
#   'release_timestamp': None,
#   'availability': None,
#   'view_count': 89673,
#   'live_status': None,
#   'channel_is_verified': True,
#   '__x_forwarded_for_ip': None},
#  {'_type': 'url',
#   'ie_key': 'Youtube',
#   'id': 'wStjS4Sbd4k',
#   'url': 'https://www.youtube.com/watch?v=wStjS4Sbd4k',
#   'title': 'MY FPL 31 TEAM SELECTION! 📱 HAALAND STARTING? 🤔 | Fantasy Premier League Tips 2025/26',
#   'description': 'Here is my new FPL GW31 Team Selection!\n🏆 Previous 5 FPL Ranks: 510th, 1,345th, 3,814th, 5,401st & 6,470th! \n_____________\nLEAGUE CODES\n🏆 Subscriber League: Code: 5s23tm - link: https://fanta...',
#   'duration': 1028.0,
#   'channel_id': None,
#   'channel': None,
#   'channel_url': None,
#   'uploader': None,
#   'uploader_id': None,
#   'uploader_url': None,
#   'thumbnails': [{'url': 'https://i.ytimg.com/vi/wStjS4Sbd4k/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLCOAbq4WeIwLPLjDyjkU8fHNH56Rw',
#     'height': 94,
#     'width': 168},
#    {'url': 'https://i.ytimg.com/vi/wStjS4Sbd4k/hqdefault.jpg?sqp=-oaymwEbCMQBEG5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLDM6Rabgk6YR8ixPt7k51iCyJ-_jA',
#     'height': 110,
#     'width': 196},
#    {'url': 'https://i.ytimg.com/vi/wStjS4Sbd4k/hqdefault.jpg?sqp=-oaymwEcCPYBEIoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDdnSxvRH8N68dhOu0YNOWU80fiEw',
#     'height': 138,
#     'width': 246},
#    {'url': 'https://i.ytimg.com/vi/wStjS4Sbd4k/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAuSgGo4ZBem-0Sq8yzHrnNg8zWiQ',
#     'height': 188,
#     'width': 336}],
#   'timestamp': None,
#   'release_timestamp': None,
#   'availability': None,
#   'view_count': 79623,
#   'live_status': None,
#   'channel_is_verified': True,
#   '__x_forwarded_for_ip': None},
#  {'_type': 'url',
#   'ie_key': 'Youtube',
#   'id': 'Zc_9A4ShrRE',
#   'url': 'https://www.youtube.com/watch?v=Zc_9A4ShrRE',
#   'title': 'MY FPL BLANK GW31 TRANSFER TARGETS! ♻️ Timber Replacements? ⚠️ | Fantasy Premier League Tips 2025/26',
#   'description': 'Here are some of the best players to buy into your FPL team for Gameweek 31!\n🏆 Previous 5 FPL Ranks: 510th, 1,345th, 3,814th, 5,401st & 6,470th! \n_____________\nLEAGUE CODES\n🏆 Subscriber...',
#   'duration': 1198.0,
#   'channel_id': None,
#   'channel': None,
#   'channel_url': None,
#   'uploader': None,
#   'uploader_id': None,
#   'uploader_url': None,
#   'thumbnails': [{'url': 'https://i.ytimg.com/vi/Zc_9A4ShrRE/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLDAUZwY3M4QEhktDgjuvLSwa5ChPQ',
#     'height': 94,
#     'width': 168},
#    {'url': 'https://i.ytimg.com/vi/Zc_9A4ShrRE/hqdefault.jpg?sqp=-oaymwEbCMQBEG5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLDABPQswoOlPivG4HGp6c5q-j6iIA',
#     'height': 110,
#     'width': 196},
#    {'url': 'https://i.ytimg.com/vi/Zc_9A4ShrRE/hqdefault.jpg?sqp=-oaymwEcCPYBEIoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBUX-lSSzFIh_kanMOpT-Vv0dfi_Q',
#     'height': 138,
#     'width': 246},
#    {'url': 'https://i.ytimg.com/vi/Zc_9A4ShrRE/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAGrDw2UcF9foY5fNQdu4j23yyW9g',
#     'height': 188,
#     'width': 336}],
#   'timestamp': None,
#   'release_timestamp': None,
#   'availability': None,
#   'view_count': 58579,
#   'live_status': None,
#   'channel_is_verified': True,
#   '__x_forwarded_for_ip': None},
#  {'_type': 'url',
#   'ie_key': 'Youtube',
#   'id': 'TyL42pxTang',
#   'url': 'https://www.youtube.com/watch?v=TyL42pxTang',
#   'title': 'FPL BLANK GW31 GAMEWEEK PREVIEW 🔮 FREE HIT DRAFT 🍟 | Fantasy Premier League Tips 2025/26',
#   'description': 'The Gameweek 31 Preview, Answering your Questions, looking at the fixtures, the data and Wildcard and Free Hit Drafts!\n\n🏆 Previous 5 FPL Ranks: 510th, 1,345th, 3,814th, 5,401st & 6,470th!...',
#   'duration': 1226.0,
#   'channel_id': None,
#   'channel': None,
#   'channel_url': None,
#   'uploader': None,
#   'uploader_id': None,
#   'uploader_url': None,
#   'thumbnails': [{'url': 'https://i.ytimg.com/vi/TyL42pxTang/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLDAD-GPJhroOmL9ZtJIxV2LYVvIBA',
#     'height': 94,
#     'width': 168},
#    {'url': 'https://i.ytimg.com/vi/TyL42pxTang/hqdefault.jpg?sqp=-oaymwEbCMQBEG5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLC2bLdN2JeS3gSXab1dwBFJYPmZzg',
#     'height': 110,
#     'width': 196},
#    {'url': 'https://i.ytimg.com/vi/TyL42pxTang/hqdefault.jpg?sqp=-oaymwEcCPYBEIoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCC2pch9YUpE40XFLwx8VBGjnmzwA',
#     'height': 138,
#     'width': 246},
#    {'url': 'https://i.ytimg.com/vi/TyL42pxTang/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLA_ijxZqPc3Ri1Z303E_ACcRW2Ovg',
#     'height': 188,
#     'width': 336}],
#   'timestamp': None,
#   'release_timestamp': None,
#   'availability': None,
#   'view_count': 61195,
#   'live_status': None,
#   'channel_is_verified': True,
#   '__x_forwarded_for_ip': None}]

# %%
def get_latest_video_urls(channel_url, limit=5):
    videos = get_latest_videos(channel_url, limit)
    return [video["url"] for video in videos]

# %%
get_latest_video_urls("https://www.youtube.com/@FPLHarry")
# Out:
# ['https://www.youtube.com/watch?v=xO6K1OsqbTM',
#  'https://www.youtube.com/watch?v=V3SO7Tt0DK8',
#  'https://www.youtube.com/watch?v=wStjS4Sbd4k',
#  'https://www.youtube.com/watch?v=Zc_9A4ShrRE',
#  'https://www.youtube.com/watch?v=TyL42pxTang']

# %% [markdown]
# ## FPL Api

# %%
# src/services/fpl_service.py
from __future__ import annotations

import requests
from typing import Any


class FPLService:
    BASE_URL = "https://fantasy.premierleague.com/api"

    def __init__(self, timeout: int = 20) -> None:
        self.timeout = timeout
        self.session = requests.Session()
        self.session.headers.update(
            {
                "User-Agent": "fpl-agent/0.1",
                "Accept": "application/json",
            }
        )

    def _get(self, path: str) -> Any:
        url = f"{self.BASE_URL}{path}"
        response = self.session.get(url, timeout=self.timeout)
        response.raise_for_status()
        return response.json()

    def get_bootstrap_static(self) -> dict[str, Any]:
        return self._get("/bootstrap-static/")

    def get_fixtures(self) -> list[dict[str, Any]]:
        return self._get("/fixtures/")

    def get_event_live(self, gameweek: int) -> dict[str, Any]:
        return self._get(f"/event/{gameweek}/live/")

    def get_element_summary(self, player_id: int) -> dict[str, Any]:
        return self._get(f"/element-summary/{player_id}/")

    def get_entry(self, team_id: int) -> dict[str, Any]:
        return self._get(f"/entry/{team_id}/")

    def get_entry_picks(self, team_id: int, gameweek: int) -> dict[str, Any]:
        return self._get(f"/entry/{team_id}/event/{gameweek}/picks/")

# %%
import pandas as pd

fpl = FPLService()
bootstrap = fpl.get_bootstrap_static()

players_df = pd.DataFrame(bootstrap["elements"])[
    [
        "id",
        "first_name",
        "second_name",
        "web_name",
        "team",
        "element_type",
        "now_cost",
        "total_points",
        "minutes",
        "goals_scored",
        "assists",
        "selected_by_percent",
    ]
]

teams_df = pd.DataFrame(bootstrap["teams"])[
    [
        "id",
        "name",
        "short_name",
        "strength",
        "strength_attack_home",
        "strength_attack_away",
        "strength_defence_home",
        "strength_defence_away",
    ]
]

gameweeks_df = pd.DataFrame(bootstrap["events"])[
    [
        "id",
        "name",
        "deadline_time",
        "finished",
        "is_current",
        "is_next",
    ]
]

# %%
players_df.head(50)
# Out:
#      id first_name            second_name         web_name  team  \
# 0     1      David            Raya Martín             Raya     1
# 1     2       Kepa  Arrizabalaga Revuelta     Arrizabalaga     1
# 2     3       Karl                   Hein             Hein     1
# 3     4      Tommy                Setford          Setford     1
# 4     5    Gabriel   dos Santos Magalhães          Gabriel     1
# 5     6    William                 Saliba           Saliba     1
# 6     7   Riccardo              Calafiori        Calafiori     1
# 7     8    Jurriën                 Timber         J.Timber     1
# 8     9      Jakub                 Kiwior           Kiwior     1
# 9    10      Myles           Lewis-Skelly     Lewis-Skelly     1
# 10   11   Benjamin                  White            White     1
# 11   13    Brayden                 Clarke           Clarke     1
# 12   14    Maldini                Kacurri          Kacurri     1
# 13   15       Josh                Nichols          Nichols     1
# 14   16     Bukayo                   Saka             Saka     1
# 15   17     Martin               Ødegaard         Ødegaard     1
# 16   18       Noni                Madueke          Madueke     1
# 17   19    Gabriel       Martinelli Silva       Martinelli     1
# 18   20    Leandro               Trossard         Trossard     1
# 19   21     Declan                   Rice             Rice     1
# 20   22      Mikel           Merino Zazón           Merino     1
# 21   23      Fábio        Ferreira Vieira     Fábio Vieira     1
# 22   24  Christian               Nørgaard         Nørgaard     1
# 23   25      Ethan                Nwaneri          Nwaneri     1
# 24   26     Martín       Zubimendi Ibáñez        Zubimendi     1
# 25   28     Ismeal                  Kabia            Kabia     1
# 26   29     Albert          Sambi Lokonga            Sambi     1
# 27   30        Kai                Havertz          Havertz     1
# 28   31    Gabriel      Fernando de Jesus          G.Jesus     1
# 29  266   Eberechi                    Eze              Eze     1
# 30  662  Cristhian               Mosquera         Mosquera     1
# 31  666     Viktor               Gyökeres         Gyökeres     1
# 32  700        Max                 Dowman           Dowman     1
# 33  711      Andre        Harriman-Annous  Harriman-Annous     1
# 34  725      Piero               Hincapié         Hincapie     1
# 35  759      Marli                 Salmon           Salmon     1
# 36   32   Emiliano        Martínez Romero         Martinez     2
# 37   33      Marco                  Bizot          M.Bizot     2
# 38   34        Joe                  Gauci            Gauci     2
# 39   35      Filip              Marschall        Marschall     2
# 40   36      Matty                   Cash             Cash     2
# 41   37      Lucas                  Digne            Digne     2
# 42   38       Ezri            Konsa Ngoyo            Konsa     2
# 43   39        Ian                Maatsen          Maatsen     2
# 44   40     Tyrone                  Mings            Mings     2
# 45   41        Pau                 Torres              Pau     2
# 46   42     Andrés                 García         A.García     2
# 47   43       Álex          Moreno Lopera      Alex Moreno     2
# 48   44     Lamare                Bogarde          Bogarde     2
# 49   45       Lino          da Cruz Sousa            Sousa     2
#
#     element_type  now_cost  total_points  minutes  goals_scored  assists  \
# 0              1        60           129     2790             0        0
# 1              1        40             0        0             0        0
# 2              1        40             0        0             0        0
# 3              1        39             0        0             0        0
# 4              2        72           173     2165             3        4
# 5              2        61           107     2074             1        0
# 6              2        56            93     1446             1        2
# 7              2        63           149     2452             3        6
# 8              2        54             0        0             0        0
# 9              2        50            12      311             0        0
# 10             2        51            30      409             0        1
# 11             2        37             0        0             0        0
# 12             2        39             0        0             0        0
# 13             2        37             0        0             0        0
# 14             3        98           133     1995             6        8
# 15             3        78            62     1070             1        6
# 16             3        68            54      889             2        1
# 17             3        68            47      839             1        4
# 18             3        66            99     1675             5        5
# 19             3        73           163     2580             4        9
# 20             3        54            66      996             4        3
# 21             3        54             0        0             0        0
# 22             3        51             6       56             0        0
# 23             3        50             8      165             0        0
# 24             3        51           117     2597             5        1
# 25             3        45             0        0             0        0
# 26             3        45             0        0             0        0
# 27             4        73            12      261             0        1
# 28             4        64            17      304             2        0
# 29             3        72            94     1494             6        3
# 30             2        53            28      667             0        0
# 31             4        88           101     1888            11        0
# 32             3        42            11       43             1        1
# 33             3        44             0        0             0        0
# 34             2        51            74     1499             1        2
# 35             2        40             0        0             0        0
# 36             1        51           105     2385             0        0
# 37             1        42            11      405             0        0
# 38             1        40             0        0             0        0
# 39             1        40             0        0             0        0
# 40             2        47           106     2442             3        2
# 41             2        45            85     1549             0        5
# 42             2        44            95     2675             0        1
# 43             2        42            40     1251             0        0
# 44             2        43            44      962             0        1
# 45             2        43            56     1386             0        1
# 46             2        39             3       37             0        0
# 47             2        40             0        0             0        0
# 48             2        40            34      797             0        0
# 49             2        38             0        0             0        0
#
#    selected_by_percent
# 0                 34.6
# 1                  0.4
# 2                  0.2
# 3                  0.2
# 4                 43.0
# 5                 13.2
# 6                  6.0
# 7                 26.8
# 8                  0.0
# 9                  1.4
# 10                 0.5
# 11                 0.4
# 12                 0.1
# 13                 0.2
# 14                 8.0
# 15                 1.5
# 16                 0.9
# 17                 0.9
# 18                 0.8
# 19                26.2
# 20                 0.8
# 21                 0.0
# 22                 0.1
# 23                 0.1
# 24                 3.6
# 25                 0.1
# 26                 0.0
# 27                 0.5
# 28                 0.3
# 29                 7.9
# 30                 0.1
# 31                11.6
# 32                 0.6
# 33                 0.0
# 34                 0.9
# 35                 0.0
# 36                 4.8
# 37                 0.4
# 38                 0.1
# 39                 0.0
# 40                 8.6
# 41                 1.6
# 42                 8.2
# 43                 0.6
# 44                 0.7
# 45                 0.3
# 46                 0.2
# 47                 1.6
# 48                 0.5
# 49                 0.3

# %%
teams_df.head()
# Out:
#    code  draw  form  id  loss         name  played  points  position  \
# 0     3     0  None   1     0      Arsenal       0       0         1
# 1     7     0  None   2     0  Aston Villa       0       0         4
# 2    90     0  None   3     0      Burnley       0       0        19
# 3    91     0  None   4     0  Bournemouth       0       0        13
# 4    94     0  None   5     0    Brentford       0       0         7
#
#   short_name  ...  team_division unavailable  win  strength_overall_home  \
# 0        ARS  ...           None       False    0                   1300
# 1        AVL  ...           None       False    0                   1155
# 2        BUR  ...           None       False    0                    975
# 3        BOU  ...           None       False    0                   1130
# 4        BRE  ...           None       False    0                   1140
#
#    strength_overall_away  strength_attack_home  strength_attack_away  \
# 0                   1365                  1340                  1390
# 1                   1225                  1120                  1230
# 2                   1090                   910                  1090
# 3                   1205                  1040                  1190
# 4                   1225                  1110                  1170
#
#    strength_defence_home  strength_defence_away  pulse_id
# 0                   1260                   1340         1
# 1                   1190                   1220         2
# 2                   1040                   1090        43
# 3                   1220                   1220       127
# 4                   1170                   1280       130
#
# [5 rows x 21 columns]

# %%
gameweeks_df.head()
# Out:
#    id        name         deadline_time release_time  average_entry_score  \
# 0   1  Gameweek 1  2025-08-15T17:30:00Z         None                   54
# 1   2  Gameweek 2  2025-08-22T17:30:00Z         None                   51
# 2   3  Gameweek 3  2025-08-30T10:00:00Z         None                   48
# 3   4  Gameweek 4  2025-09-13T10:00:00Z         None                   63
# 4   5  Gameweek 5  2025-09-20T10:00:00Z         None                   42
#
#    finished  data_checked  highest_scoring_entry  deadline_time_epoch  \
# 0      True          True              3772644.0           1755279000
# 1      True          True              2963810.0           1755883800
# 2      True          True              4374360.0           1756548000
# 3      True          True              7997042.0           1757757600
# 4      True          True              9985225.0           1758362400
#
#    deadline_time_game_offset  ...  ranked_count  \
# 0                          0  ...       9469118
# 1                          0  ...      10752422
# 2                          0  ...      11304791
# 3                          0  ...      11641518
# 4                          0  ...      11803614
#
#                                            overrides  \
# 0  {'rules': {}, 'scoring': {}, 'element_types': ...
# 1  {'rules': {}, 'scoring': {}, 'element_types': ...
# 2  {'rules': {}, 'scoring': {}, 'element_types': ...
# 3  {'rules': {}, 'scoring': {}, 'element_types': ...
# 4  {'rules': {}, 'scoring': {}, 'element_types': ...
#
#                                           chip_plays  most_selected  \
# 0  [{'chip_name': 'bboost', 'num_played': 342779}...          235.0
# 1  [{'chip_name': 'bboost', 'num_played': 206501}...          235.0
# 2  [{'chip_name': 'bboost', 'num_played': 181694}...          249.0
# 3  [{'chip_name': 'bboost', 'num_played': 151177}...          249.0
# 4  [{'chip_name': 'bboost', 'num_played': 231274}...          249.0
#
#    most_transferred_in  top_element           top_element_info  \
# 0                  1.0        531.0  {'id': 531, 'points': 17}
# 1                427.0          8.0    {'id': 8, 'points': 24}
# 2                 82.0        260.0  {'id': 260, 'points': 15}
# 3                419.0         26.0   {'id': 26, 'points': 16}
# 4                 82.0        660.0  {'id': 660, 'points': 15}
#
#    transfers_made  most_captained  most_vice_captained
# 0               0           381.0                235.0
# 1        18178809           381.0                235.0
# 2        27802596           430.0                381.0
# 3        27408255           381.0                249.0
# 4        16533109           381.0                249.0
#
# [5 rows x 29 columns]
